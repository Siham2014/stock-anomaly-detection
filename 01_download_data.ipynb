# %%
# Cell 1 - Vérification des packages CORRIGÉE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
import sklearn

print("✅ Tous les packages essentiels sont installés!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Scikit-learn version: {sklearn.__version__}")

# Test Isolation Forest
print("🔍 Isolation Forest disponible : OUI")
# Out:
# ✅ Tous les packages essentiels sont installés!
# Pandas version: 2.2.2
# NumPy version: 1.26.4
# Scikit-learn version: 1.5.1
# 🔍 Isolation Forest disponible : OUI

# %%
# Cell 2 - Installation package Azure
try:
    from azure.storage.blob import BlobServiceClient
    print("✅ Package azure-storage-blob déjà installé")
except ImportError:
    print("📦 Installation du package azure-storage-blob...")
    # !pip install azure-storage-blob
    from azure.storage.blob import BlobServiceClient
# Out:
# 📦 Installation du package azure-storage-blob...
# ...
#   Using cached azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# ...
#   Using cached azure_core-1.36.0-py3-none-any.whl.metadata (47 kB)
# ...
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
# Using cached azure_core-1.36.0-py3-none-any.whl (213 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# ...

# %%
# Cell 3 - Téléchargement depuis Azure Blob Storage
import os

# ⚠️ REMPLACEZ par votre vraie chaîne de connexion
connection_string = "change me"
container_name = "stock-training-data"
blob_name = "processed/stock_data_cleaned_mlops.csv"
local_filename = "stock_data.csv"

try:
    print("🔗 Connexion à Azure Blob Storage...")
    blob_service = BlobServiceClient.from_connection_string(connection_string)
    container_client = blob_service.get_container_client(container_name)
    blob_client = container_client.get_blob_client(blob_name)
    
    print("📥 Téléchargement en cours...")
    with open(local_filename, "wb") as file:
        download_stream = blob_client.download_blob()
        file.write(download_stream.readall())
    
    print(f"✅ SUCCÈS : Fichier téléchargé → {local_filename}")
    print(f"📊 Taille : {os.path.getsize(local_filename)} bytes")
    
except Exception as e:
    print(f"❌ ERREUR : {e}")
# Out:
# 🔗 Connexion à Azure Blob Storage...
# 📥 Téléchargement en cours...
# ✅ SUCCÈS : Fichier téléchargé → stock_data.csv
# 📊 Taille : 115852 bytes
